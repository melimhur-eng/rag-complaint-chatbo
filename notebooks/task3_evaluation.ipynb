# %%
questions = [
    "Why are customers unhappy with credit cards?",
    "What complaints are common in money transfers?",
    "What fraud issues appear in personal loans?",
    "What problems occur with savings accounts?",
    "Which product receives the most complaints?"
]

# %%
from src.rag_pipeline import ComplaintRAG

rag = ComplaintRAG("../vector_store/faiss_index")

for q in questions:

    result = rag.ask(q)

    print("="*50)
    print(q)
    print(result["answer"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.rag_pipeline import ComplaintRAG
#       2
#       3 rag = ComplaintRAG("../vector_store/faiss_index")
#       4
#
# ModuleNotFoundError: No module named 'src'
