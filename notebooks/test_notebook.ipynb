# %%
import pandas as pd

full = pd.read_csv("data/processed/filtered_complaints.csv")
sample = pd.read_csv("data/processed/sample_complaints.csv")

print("FULL")
print(full["Product"].value_counts(normalize=True))

print("\nSAMPLE")
print(sample["Product"].value_counts(normalize=True))

# %%
import pandas as pd

df = pd.read_csv("data/processed/filtered_complaints.csv")

print(df["Product"].value_counts())
